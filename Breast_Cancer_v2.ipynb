# %% [markdown]
# # Using Cell Nuclei Characteristics to Diagnose Breast Cancer through Supervized Machine Learning

# %% [markdown]
# 1. Preparing the Dataset
# 2. Exploratory Data Analysis
# 3. Data Splitting
# 4. Training Machine Learning Models (kNN, Naive Bayes, Log Regression, SVM)
# 5. Cross-Validation
# 6. Fine-Tuning of Hyperparameters
# 7. Feature Importance
# 8. Deployment

# %% [markdown]
# In this notebook, we will be aiming to classify breast cancer cells as benign or malignant using physical characteristics of their cell nuclei. The classification algorithm that will be used are supervized machine learning models, which will be deployed in a web-app.
#
# The data is taken from: https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic.

# %% [markdown]
# # Preparing the Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split

# %% [markdown]
# The dataset is inputted into a dataframe.

# %%
cols = ['ID', 'Diagnosis', 'radius1', 'texture1', 'perimeter1', 'area1', 'smoothness1', 'compactness1', 'concavity1', 'concave_points1', 'symmetry1', 'fractal_dimension1', 'radius2','texture2', 'perimeter2', 'area2', 'smoothness2', 'compactness2', 'concavity2', 'concave_points2', 'symmetry2', 'fractal_dimension2', 'radius3', 'texture3', 'perimeter3', 'area3', 'smoothness3', 'compactness3', 'concavity3', 'concave_points3', 'symmetry', 'fractal_dimension']
df = pd.read_csv('wdbc.data', names = cols)
df.head()
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    842302         M    17.99     10.38      122.80  1001.0      0.11840
# 1    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 2  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 3  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 4  84358402         M    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.27760      0.3001          0.14710  ...    25.38     17.33
# 1       0.07864      0.0869          0.07017  ...    24.99     23.41
# 2       0.15990      0.1974          0.12790  ...    23.57     25.53
# 3       0.28390      0.2414          0.10520  ...    14.91     26.50
# 4       0.13280      0.1980          0.10430  ...    22.54     16.67
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# 0      184.60  2019.0       0.1622        0.6656      0.7119           0.2654
# 1      158.80  1956.0       0.1238        0.1866      0.2416           0.1860
# 2      152.50  1709.0       0.1444        0.4245      0.4504           0.2430
# 3       98.87   567.7       0.2098        0.8663      0.6869           0.2575
# 4      152.20  1575.0       0.1374        0.2050      0.4000           0.1625
#
#    symmetry  fractal_dimension
# 0    0.4601            0.11890
# 1    0.2750            0.08902
# 2    0.3613            0.08758
# 3    0.6638            0.17300
# 4    0.2364            0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# The categorical data that we are trying to predict, the diagnosis, is casted as integers, with the following legends:
# * B (benign): 0
# * M (malignant): 1
#
# We also dropped the column ID, as they are not relevant to the analysis.
#
# The continuous data are marked with 1, 2, or 3, indicating their data type:
# * 1: mean
# * 2: standard error
# * 3: worst (mean of the three largest values of the features computed for the images)

# %%
df["Diagnosis"] = (df["Diagnosis"] == "M").astype(int)
df = df.drop("ID", axis = 1)
df.head()
# Out:
#    Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0          1    17.99     10.38      122.80  1001.0      0.11840
# 1          1    20.57     17.77      132.90  1326.0      0.08474
# 2          1    19.69     21.25      130.00  1203.0      0.10960
# 3          1    11.42     20.38       77.58   386.1      0.14250
# 4          1    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  symmetry1  ...  radius3  \
# 0       0.27760      0.3001          0.14710     0.2419  ...    25.38
# 1       0.07864      0.0869          0.07017     0.1812  ...    24.99
# 2       0.15990      0.1974          0.12790     0.2069  ...    23.57
# 3       0.28390      0.2414          0.10520     0.2597  ...    14.91
# 4       0.13280      0.1980          0.10430     0.1809  ...    22.54
#
#    texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0     17.33      184.60  2019.0       0.1622        0.6656      0.7119
# 1     23.41      158.80  1956.0       0.1238        0.1866      0.2416
# 2     25.53      152.50  1709.0       0.1444        0.4245      0.4504
# 3     26.50       98.87   567.7       0.2098        0.8663      0.6869
# 4     16.67      152.20  1575.0       0.1374        0.2050      0.4000
#
#    concave_points3  symmetry  fractal_dimension
# 0           0.2654    0.4601            0.11890
# 1           0.1860    0.2750            0.08902
# 2           0.2430    0.3613            0.08758
# 3           0.2575    0.6638            0.17300
# 4           0.1625    0.2364            0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# We then tried to graphed the characteristics to see visually whether or not the benign or malignant cells differ from each other.

# %%
figure, axis = plt.subplots(5, 6)
axis = axis.flatten()
plt.figure(figsize = (200, 200))

plt.rcParams.update({'font.size': 4})
figure.tight_layout(pad = 2.5)

for i in range(len(list(df.columns.values[1:]))):
    label = list(df.columns.values[1:])[i]
    axis[i].hist(df[df["Diagnosis"] == 0][label], color = "blue", label = "Benign", alpha = 0.7, density = True)
    axis[i].hist(df[df["Diagnosis"] == 1][label], color = "red", label = "Malignant", alpha = 0.7, density = True)
    axis[i].set_title(label)

lines_labels = [ax.get_legend_handles_labels() for ax in figure.axes][0:1]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
figure.legend(lines, labels, loc = 8)

plt.show()

# %% [markdown]
# As we can see, they are all important in determining whether or not a tumor cell is benign or malignant as their probability distributions are in some way, different from each other.
#
# We also ran df.describe() to see some of the summary statistics of the data.

# %%
df.describe()
# Out:
#         Diagnosis     radius1    texture1  perimeter1        area1  \
# count  569.000000  569.000000  569.000000  569.000000   569.000000
# mean     0.372583   14.127292   19.289649   91.969033   654.889104
# std      0.483918    3.524049    4.301036   24.298981   351.914129
# min      0.000000    6.981000    9.710000   43.790000   143.500000
# 25%      0.000000   11.700000   16.170000   75.170000   420.300000
# 50%      0.000000   13.370000   18.840000   86.240000   551.100000
# 75%      1.000000   15.780000   21.800000  104.100000   782.700000
# max      1.000000   28.110000   39.280000  188.500000  2501.000000
#
#        smoothness1  compactness1  concavity1  concave_points1   symmetry1  \
# count   569.000000    569.000000  569.000000       569.000000  569.000000
# mean      0.096360      0.104341    0.088799         0.048919    0.181162
# std       0.014064      0.052813    0.079720         0.038803    0.027414
# min       0.052630      0.019380    0.000000         0.000000    0.106000
# 25%       0.086370      0.064920    0.029560         0.020310    0.161900
# 50%       0.095870      0.092630    0.061540         0.033500    0.179200
# 75%       0.105300      0.130400    0.130700         0.074000    0.195700
# max       0.163400      0.345400    0.426800         0.201200    0.304000
#
#        ...     radius3    texture3  perimeter3        area3  smoothness3  \
# count  ...  569.000000  569.000000  569.000000   569.000000   569.000000
# mean   ...   16.269190   25.677223  107.261213   880.583128     0.132369
# std    ...    4.833242    6.146258   33.602542   569.356993     0.022832
# min    ...    7.930000   12.020000   50.410000   185.200000     0.071170
# 25%    ...   13.010000   21.080000   84.110000   515.300000     0.116600
# 50%    ...   14.970000   25.410000   97.660000   686.500000     0.131300
# 75%    ...   18.790000   29.720000  125.400000  1084.000000     0.146000
# max    ...   36.040000   49.540000  251.200000  4254.000000     0.222600
#
#        compactness3  concavity3  concave_points3    symmetry  \
# count    569.000000  569.000000       569.000000  569.000000
# mean       0.254265    0.272188         0.114606    0.290076
# std        0.157336    0.208624         0.065732    0.061867
# min        0.027290    0.000000         0.000000    0.156500
# 25%        0.147200    0.114500         0.064930    0.250400
# 50%        0.211900    0.226700         0.099930    0.282200
# 75%        0.339100    0.382900         0.161400    0.317900
# max        1.058000    1.252000         0.291000    0.663800
#
#        fractal_dimension
# count         569.000000
# mean            0.083946
# std             0.018061
# min             0.055040
# 25%             0.071460
# 50%             0.080040
# 75%             0.092080
# max             0.207500
#
# [8 rows x 31 columns]

# %% [markdown]
# To see for any outliers, we will be plotting the boxplots for each of the parameters, separated by benign or malignant.

# %%
benign = df[df["Diagnosis"] == 0]
malignant = df[df["Diagnosis"] == 1]
plt.rcParams.update({'font.size': 10})

for i in range(len(list(df.columns.values[1:]))):
    label = list(df.columns.values[1:])[i]
    combined_dfs = pd.DataFrame({'Benign': benign[label],
                                  'Malignant': malignant[label]})
    sns.set_style('white')
    sns.boxplot(combined_dfs).set(title = label)
    sns.despine()
    plt.show()

# %% [markdown]
# As we can see from the boxplots, there are actually many outliers.
#
# In order to see the correlation matrix, we run the following.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_70a74_row0_col0, #T_70a74_row1_col1, #T_70a74_row1_col3, #T_70a74_row2_col2, #T_70a74_row3_col1, #T_70a74_row3_col3, #T_70a74_row4_col4, #T_70a74_row5_col5, #T_70a74_row6_col6, #T_70a74_row7_col7, #T_70a74_row8_col8, #T_70a74_row9_col9, #T_70a74_row10_col10, #T_70a74_row11_col11, #T_70a74_row12_col12, #T_70a74_row13_col13, #T_70a74_row14_col14, #T_70a74_row15_col15, #T_70a74_row16_col16, #T_70a74_row17_col17, #T_70a74_row18_col18, #T_70a74_row19_col19, #T_70a74_row20_col20, #T_70a74_row21_col21, #T_70a74_row22_col22, #T_70a74_row23_col23, #T_70a74_row24_col24, #T_70a74_row25_col25, #T_70a74_row26_col26, #T_70a74_row27_col27, #T_70a74_row28_col28, #T_70a74_row29_col29, #T_70a74_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col1, #T_70a74_row0_col3, #T_70a74_row3_col28, #T_70a74_row23_col0, #T_70a74_row28_col24 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col2, #T_70a74_row2_col12, #T_70a74_row13_col27, #T_70a74_row18_col15 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_70a74_row0_col4, #T_70a74_row0_col8, #T_70a74_row1_col28, #T_70a74_row11_col21, #T_70a74_row11_col23, #T_70a74_row13_col23, #T_70a74_row20_col16 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col5, #T_70a74_row1_col2, #T_70a74_row5_col3, #T_70a74_row5_col21, #T_70a74_row5_col23, #T_70a74_row9_col0, #T_70a74_row25_col23, #T_70a74_row28_col10 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_70a74_row0_col6, #T_70a74_row14_col0, #T_70a74_row17_col10, #T_70a74_row28_col14 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_70a74_row0_col7, #T_70a74_row6_col10 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_70a74_row0_col9, #T_70a74_row2_col8, #T_70a74_row10_col18, #T_70a74_row16_col25, #T_70a74_row20_col9, #T_70a74_row22_col25, #T_70a74_row24_col18, #T_70a74_row25_col22 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_70a74_row0_col10, #T_70a74_row9_col12, #T_70a74_row20_col11, #T_70a74_row20_col25 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col11, #T_70a74_row9_col5, #T_70a74_row23_col26, #T_70a74_row26_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_70a74_row0_col12, #T_70a74_row0_col19, #T_70a74_row29_col17 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col13, #T_70a74_row3_col6, #T_70a74_row7_col30, #T_70a74_row10_col25, #T_70a74_row16_col28, #T_70a74_row18_col13, #T_70a74_row28_col13 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_70a74_row0_col14, #T_70a74_row9_col6, #T_70a74_row13_col0, #T_70a74_row14_col7, #T_70a74_row27_col29 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_70a74_row0_col15, #T_70a74_row20_col0, #T_70a74_row21_col30 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col16, #T_70a74_row5_col12, #T_70a74_row20_col21 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col17, #T_70a74_row12_col4, #T_70a74_row14_col10, #T_70a74_row20_col24, #T_70a74_row29_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col18, #T_70a74_row0_col30, #T_70a74_row3_col22, #T_70a74_row7_col2, #T_70a74_row9_col3, #T_70a74_row23_col29, #T_70a74_row30_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_70a74_row0_col20, #T_70a74_row15_col13, #T_70a74_row24_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col21, #T_70a74_row0_col23, #T_70a74_row8_col6, #T_70a74_row26_col28, #T_70a74_row30_col10 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col22, #T_70a74_row7_col10, #T_70a74_row29_col10 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_70a74_row0_col24, #T_70a74_row13_col24, #T_70a74_row28_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col25, #T_70a74_row1_col26, #T_70a74_row5_col29, #T_70a74_row7_col9, #T_70a74_row9_col30, #T_70a74_row16_col15, #T_70a74_row16_col19, #T_70a74_row17_col30, #T_70a74_row18_col14, #T_70a74_row22_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_70a74_row0_col26, #T_70a74_row18_col20, #T_70a74_row26_col16 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_70a74_row0_col27, #T_70a74_row3_col13, #T_70a74_row5_col10, #T_70a74_row14_col8, #T_70a74_row27_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_70a74_row0_col28 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_70a74_row0_col29, #T_70a74_row1_col6, #T_70a74_row2_col21, #T_70a74_row5_col7, #T_70a74_row20_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_70a74_row1_col0, #T_70a74_row18_col17, #T_70a74_row27_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_70a74_row1_col4, #T_70a74_row3_col4, #T_70a74_row4_col1, #T_70a74_row4_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col5, #T_70a74_row12_col13, #T_70a74_row13_col25, #T_70a74_row14_col17 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col7, #T_70a74_row6_col3, #T_70a74_row7_col14, #T_70a74_row24_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_70a74_row1_col8, #T_70a74_row4_col8, #T_70a74_row4_col14, #T_70a74_row5_col25, #T_70a74_row26_col30, #T_70a74_row28_col3, #T_70a74_row28_col26 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col9, #T_70a74_row2_col18 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col10, #T_70a74_row1_col20, #T_70a74_row2_col5, #T_70a74_row2_col9, #T_70a74_row10_col1, #T_70a74_row10_col2, #T_70a74_row10_col3, #T_70a74_row10_col4, #T_70a74_row10_col11, #T_70a74_row10_col13, #T_70a74_row10_col14, #T_70a74_row10_col21, #T_70a74_row10_col24, #T_70a74_row12_col6, #T_70a74_row12_col7, #T_70a74_row12_col8, #T_70a74_row12_col25, #T_70a74_row12_col26, #T_70a74_row12_col27, #T_70a74_row12_col28, #T_70a74_row12_col29, #T_70a74_row12_col30, #T_70a74_row15_col0, #T_70a74_row15_col22, #T_70a74_row15_col23, #T_70a74_row19_col22, #T_70a74_row21_col15, #T_70a74_row21_col19, #T_70a74_row22_col16, #T_70a74_row22_col17, #T_70a74_row22_col18, #T_70a74_row29_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col11, #T_70a74_row29_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_70a74_row1_col12 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col13, #T_70a74_row6_col23, #T_70a74_row16_col27, #T_70a74_row21_col7, #T_70a74_row27_col21 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_70a74_row1_col14, #T_70a74_row7_col4, #T_70a74_row11_col1, #T_70a74_row11_col3, #T_70a74_row13_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_70a74_row1_col15, #T_70a74_row15_col8, #T_70a74_row21_col20, #T_70a74_row28_col12 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col16, #T_70a74_row21_col16, #T_70a74_row29_col13, #T_70a74_row30_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col17, #T_70a74_row5_col22, #T_70a74_row12_col16, #T_70a74_row12_col17, #T_70a74_row25_col19, #T_70a74_row28_col15 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col18, #T_70a74_row6_col19, #T_70a74_row11_col5, #T_70a74_row13_col16, #T_70a74_row16_col12, #T_70a74_row18_col12, #T_70a74_row22_col29, #T_70a74_row25_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_70a74_row1_col19, #T_70a74_row3_col15, #T_70a74_row4_col10, #T_70a74_row4_col20, #T_70a74_row22_col9, #T_70a74_row23_col12, #T_70a74_row23_col19 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col21, #T_70a74_row3_col21, #T_70a74_row3_col23, #T_70a74_row13_col11, #T_70a74_row21_col3, #T_70a74_row23_col1, #T_70a74_row23_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col22, #T_70a74_row2_col27, #T_70a74_row11_col26, #T_70a74_row14_col26, #T_70a74_row15_col5, #T_70a74_row16_col14, #T_70a74_row18_col9, #T_70a74_row28_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_70a74_row1_col23, #T_70a74_row4_col21, #T_70a74_row11_col13, #T_70a74_row21_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_70a74_row1_col24, #T_70a74_row3_col24, #T_70a74_row14_

# %% [markdown]
# # Training and Testing Data Sets

# %% [markdown]
# We will be splitting the datasets in an 80-20 split, with 80% of the data going into training the model while 20% going into testing the model.
#
# Here, we define a function called *scaled dataset*, taking in the inputs *dataframe* and *oversample.* This function scales the "inputs" in order for the variables to affect the output appropriately. If the dataset oversamples one diagnoses from the other, it is recommended that the oversample parameter to be turned True as imbalances in the training dataset might cause the model to have some issues in determining a diagnosis.

# %%
def scale_dataset(dataframe, oversample = False):
  x = dataframe[dataframe.columns[1:]].values
  y = dataframe[dataframe.columns[0]].values

  scaler = StandardScaler()
  x = scaler.fit_transform(x)

  if oversample:
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x, y)

  data = np.hstack((x, np.reshape(y, (-1, 1))))
  return data, x, y

# %%
scaler = StandardScaler()
train, test = train_test_split(df, test_size = 0.2, random_state = 1, shuffle = True)
array_for_x_training = scaler.fit_transform(train[train.columns[1:]].values)

# %%
train, x_train, y_train = scale_dataset(train, oversample = True)
test, x_test, y_test = scale_dataset(test, oversample = False)

# %% [markdown]
# # Training Machine Learning Models and Cross-Validation

# %% [markdown]
# In this section, we will be training the machine learning models that have the default settings. We will be using the f1 score to decide what machine learning model we will select to fine-tune its hyperparameters. In addition, we will be cross-validating all of the machine learning models to avoid the effects of randomness.

# %% [markdown]
# We will be creating a dictionary for the f1-score for the positive (malignant), the metric that we will be using, to keep track of the sores and help us decide what model to choose.

# %%
f1_metric = {}

# %% [markdown]
# ## k-Nearest Neighbors

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(x_train, y_train)
y_pred = knn_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        72
#            1       0.95      0.88      0.91        42
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
scores  = cross_val_score(knn_model,
                         x_train,
                         y_train,
                         scoring = 'f1',
                         cv = 15)
f1_metric['knn'] = scores.mean()
print(f1_metric['knn'])
# Out:
# 0.9634561281929703

# %% [markdown]
# We can see that the f1 score of k-nearest neighbors, with k = 5, has a score of 0.9635.

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model.fit(x_train, y_train)
y_pred = nb_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        72
#            1       0.91      0.93      0.92        42
#
#     accuracy                           0.94       114
#    macro avg       0.93      0.94      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
scores  = cross_val_score(nb_model,
                         x_train,
                         y_train,
                         scoring = 'f1',
                         cv = 15)
f1_metric['nb_model'] = scores.mean()
print(f1_metric['nb_model'])
# Out:
# 0.9253363716521613

# %% [markdown]
# We can see that Naive Bayes returned an f1 score of 0.9253, which is lower than the f1 score of 5 nearest neighbors (0.9635).

# %% [markdown]
# ## Log Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_model = LogisticRegression()
lg_model.fit(x_train, y_train)
y_pred = lg_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        72
#            1       0.95      0.95      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
scores  = cross_val_score(lg_model,
                         x_train,
                         y_train,
                         scoring = 'f1',
                         cv = 15)
f1_metric['lg_model'] = scores.mean()
print(f1_metric['lg_model'])
# Out:
# 0.9792777669542754

# %% [markdown]
# We can see that  returned an f1 score of 0.9793, which is higher than the f1 score of 5 nearest neighbors (0.9253).

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()
svm_model.fit(x_train, y_train)
y_pred = svm_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        72
#            1       0.98      0.95      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
scores  = cross_val_score(svm_model,
                         x_train,
                         y_train,
                         scoring = 'f1',
                         cv = 15)
f1_metric['svm_model'] = scores.mean()
print(f1_metric['svm_model'])
# Out:
# 0.9772136103715051

# %% [markdown]
# We can see that  returned an f1 score of 0.9772, which is higher than the f1 score of logistic regression (0.9253).

# %% [markdown]
# ## Summary

# %% [markdown]
# Here, we will be plotting the values of f1_metric in order to compare their values to each other.

# %%
import math

# %%
x = list(f1_metric.keys())
y = list(f1_metric.values())
plt.ylim(0.9, 1)
plt.bar(range(len(f1_metric)), y, tick_label = x)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# We can see that support vector machines has the f1 score, which means that it will be the one selected for fine-tuning.

# %% [markdown]
# # Fine-Tuning of Parameters

# %% [markdown]
# We will be fine-tuning the parameters of the SVM model to best-fit the data.

# %%
from sklearn.model_selection import GridSearchCV

# %%
# C = 1, 2, 4, 16, 32 --> 16 --> 14, 15, 16, 17, 18 --> 12, 13, 14, 15, 16
# tol = [1e-3, 1e-4, 1e-2, 1e-1, 1e-5]

parameters = [{'C': [],
               'kernel': ['rbf'],
               # 'degree': [0, 1, 2, 3, 4]}]
               'gamma': ['scale'],
               # 'coef0': [0, 0.5, 1, 2, 4],
               'shrinking': [True, False],
               'probability': [True, False],
               'tol': [1e-3],
               'class_weight': ['balanced', None],
               'break_ties': [True, False]}]

# %%
gridsearch_svm = GridSearchCV(svm_model,
                              param_grid = parameters,
                              scoring = 'f1',
                              cv = 10)

# %%
gridsearch_svm.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid=[{'C': [12, 13, 14, 15, 16],
#                           'break_ties': [True, False],
#                           'class_weight': ['balanced', None],
#                           'gamma': ['scale'], 'kernel': ['rbf'],
#                           'probability': [True, False],
#                           'shrinking': [True, False], 'tol': [0.001]}],
#              scoring='f1')

# %%
gridsearch_svm.best_params_
# Out:
# {'C': 12,
#  'break_ties': True,
#  'class_weight': 'balanced',
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'probability': True,
#  'shrinking': True,
#  'tol': 0.001}

# %%
gridsearch_svm.score(x_train, y_train)
# Out:
# 0.9947275922671354

# %% [markdown]
# Because of this, we can say that the model is the most useful when:
# * C = 14
# * kernel = rbf
# * gamma = scale
# * shrinking = True
# * probability = True
# * tol = 0.001
# * class_weight = balanced

# %% [markdown]
# # Feature Importance
#
# Feature importance is looked into in order to determine which of the features has the most influence on the model's decision.

# %%
from sklearn.inspection import permutation_importance

# %% [markdown]
# The function below is taken from https://inria.github.io/scikit-learn-mooc/python_scripts/dev_features_importance.html#feature-importance-by-permutation.

# %%
def plot_feature_importances(perm_importance_result, feat_name):
    """bar plot the feature importance"""

    fig, ax = plt.subplots()

    indices = perm_importance_result["importances_mean"].argsort()
    plt.barh(
        range(len(indices)),
        perm_importance_result["importances_mean"][indices],
        xerr=perm_importance_result["importances_std"][indices],
    )

    ax.set_yticks(range(len(indices)))
    _ = ax.set_yticklabels(feat_name[indices])

# %%
perm_importance_result_train = permutation_importance(gridsearch_svm, x_train, y_train, n_repeats = 10)

# %%
plot_feature_importances(perm_importance_result_train, df.columns[1:])

# %% [markdown]
# As we can see here, the largest measurement of texture (texture3), the standard error of radius (radius2), and the standard error of compactness (compactness2) has the most effect in determining the diagnosis of a breast cancer cell as being malignant or benign.
